# %% [markdown]
# <a href="https://colab.research.google.com/github/OviedoVR/CloudSolved/blob/main/Storytelling_matplotlib_TipsDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Storytelling with Matplotlib**
#
# ---
#
# *by* `Vinícius Oviedo` | [Linkedin](https://www.linkedin.com/in/vinicius-oviedo/) | [GitHub](https://github.com/OviedoVR) | [Medium](https://medium.com/@vo.freelancer5) | [Services Web Page](https://vinicius-oviedo.streamlit.app/)

# %% [markdown]
# ### **Imports**

# %%
# arrays:
import numpy as np       

# data manipulation:
import pandas as pd

# data visualization:
import matplotlib.pyplot as plt

# data visualization (source of some datasets):
import seaborn as sns

# high-quality exporting images
from IPython import display
display.set_matplotlib_formats('svg')

# %% [markdown]
# ### **Configuration of matplotlib custom theme**

# %% [markdown]
# >**More information** can be found at: https://matplotlib.org/stable/tutorials/introductory/customizing.html.

# %%
# customizations:
plt.rcParams['font.family'] = 'monospace'
plt.rcParams['font.size'] = 8
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.titlecolor'] = 'black'
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['axes.spines.top'] = False 
plt.rcParams['axes.spines.right'] = False 
plt.rcParams['axes.labelcolor'] = 'darkgray'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.edgecolor'] = 'darkgray'
plt.rcParams['axes.linewidth'] = 0.2
plt.rcParams['ytick.color'] = 'darkgray'
plt.rcParams['xtick.color'] = 'darkgray'

# %% [markdown]
# ### **Loading the data**

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ### **Creating a new calculated column**

# %%
tips['perc_bill'] = tips['tip'] / tips['total_bill'] * 100
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  perc_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
# obtaining the descriptive statistics to support the story to be told:
tips.describe()
# Out:
#        total_bill         tip        size   perc_bill
# count  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672   16.080258
# std      8.902412    1.383638    0.951100    6.107220
# min      3.070000    1.000000    1.000000    3.563814
# 25%     13.347500    2.000000    2.000000   12.912736
# 50%     17.795000    2.900000    2.000000   15.476977
# 75%     24.127500    3.562500    3.000000   19.147549
# max     50.810000   10.000000    6.000000   71.034483

# %% [markdown]
# ### **Creating the chart**

# %%
# creating a figure/axes:
fig, ax = plt.subplots()

# first graph (background):
plt.scatter(
      tips['total_bill'],
      tips['perc_bill'],
      color='darkgray',
      alpha=0.3     
  )

# second graph (highlighted information):
tips_highlight = tips.query('perc_bill >= 20')
plt.scatter(
      tips_highlight['total_bill'],
      tips_highlight['perc_bill'],
      color='#5D3FD3',
      alpha=0.7
  )

# Title and axis-labels:
plt.title('How many waiters receive tips that represent more\nthan 20% of total bill?', loc='left', pad=5)
plt.xlabel('Total bill ($)')
plt.ylabel('Tip: % of\ntotal bill ($)', rotation=0, labelpad=35)
# text elements:
plt.text(15, 35,
         'Only 1 of 4 waiters receive at least\n20% of  total bill as a tip',
         color = '#5D3FD3',
         verticalalignment='center',
         ha='left',
         size=7);

# Exporting it as a figure:
plt.tight_layout()
plt.savefig('Storytelling-Python-matplotlib.png', dpi=1200)

# %% [markdown]
# ### **Other examples**

# %%
# Creating a figure/axes:
fig, ax = plt.subplots()

# First chart:
plt.scatter(
      tips['total_bill'],
      tips['tip'],
      color='lightgray',
  )

# Second chart:
tips_hl = tips.query('tip >=8 | total_bill >= 40')  # hightlighted information
plt.scatter(
      tips_hl['total_bill'],
      tips_hl['tip'],
      color='Crimson',
      s=25
  )

# Linking the colorful points:
plt.plot(
      tips_hl['total_bill'],
      tips_hl['tip'],
      color='Crimson',
      alpha=0.7,
      ls='-.'
  )

# Title and axis labels:
plt.text(33, 9.75, 'These points are unusual', color='Crimson',  weight='bold')
plt.text(7.5, 7.25, 'These points are the ordinary ones', color='lightgray', weight='bold')
plt.title('Storytelling with data')
plt.xlabel('Total bill ($)')
plt.ylabel('Tip ($)')

# Exporting it as a figure:
plt.tight_layout()
plt.savefig('bonus_storytelling_e1.png', dpi=1200)

# %%
# Creating a figure/axes:
fig, ax = plt.subplots()

# First chart:
plt.scatter(
      tips['total_bill'],
      tips['tip'],
      color='darkgray'
  )

# Second chart:
tips_i = tips.query('tip <= 2.75 & total_bill > 20') # hightlighted information
plt.scatter(
      tips_i['total_bill'],
      tips_i['tip'],
      color='RoyalBlue',
      alpha=0.6
  )

# Title and axis labels:
plt.text(5, 7.25, 'These point are the ordinary ones', color='lightgray', weight='bold')
plt.text(35, 0.75, 'These points have more\ntotal bill values, but\nthe tip were lesser than\nthe mean tip', color='RoyalBlue', size=8, weight='bold')
plt.title('Storytelling with data')
plt.xlabel('Total bill ($)')
plt.ylabel('Tip ($)')

# Exporting it as a figure:
plt.tight_layout()
plt.savefig('bonus_storytelling_e2.png', dpi=1200)
